# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import quandl
# %matplotlib inline

# %%
quandl.ApiConfig.api_key = 'F9JWpzy2KzrfvA7kRzm4'

# %%
intc = quandl.get('WIKI/INTC',start_date='2016-1-1')

# %%
intc.tail()
# Out:
#              Open   High    Low  Close      Volume  Ex-Dividend  Split Ratio  \
# Date
# 2018-03-21  51.55  52.17  51.17  51.56  22984769.0          0.0          1.0
# 2018-03-22  50.74  51.96  50.60  50.83  30650151.0          0.0          1.0
# 2018-03-23  50.59  50.99  49.36  49.36  36741700.0          0.0          1.0
# 2018-03-26  50.74  52.49  50.32  52.48  37527480.0          0.0          1.0
# 2018-03-27  53.01  53.25  50.78  51.19  37076576.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 2018-03-21      51.55      52.17     51.17       51.56   22984769.0
# 2018-03-22      50.74      51.96     50.60       50.83   30650151.0
# 2018-03-23      50.59      50.99     49.36       49.36   36741700.0
# 2018-03-26      50.74      52.49     50.32       52.48   37527480.0
# 2018-03-27      53.01      53.25     50.78       51.19   37076576.0

# %%
nvda = quandl.get('WIKI/NVDA',start_date='2016-1-1')

# %%
nvda.tail()
# Out:
#               Open    High      Low   Close      Volume  Ex-Dividend  \
# Date
# 2018-03-21  249.32  252.00  247.330  248.56  10841782.0          0.0
# 2018-03-22  246.00  247.88  240.341  241.85  13663927.0          0.0
# 2018-03-23  242.40  242.67  232.520  232.97  18225390.0          0.0
# 2018-03-26  238.00  244.53  235.900  244.48  15130542.0          0.0
# 2018-03-27  247.75  250.00  219.845  225.52  34462113.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2018-03-21          1.0     249.32     252.00   247.330      248.56
# 2018-03-22          1.0     246.00     247.88   240.341      241.85
# 2018-03-23          1.0     242.40     242.67   232.520      232.97
# 2018-03-26          1.0     238.00     244.53   235.900      244.48
# 2018-03-27          1.0     247.75     250.00   219.845      225.52
#
#             Adj. Volume
# Date
# 2018-03-21   10841782.0
# 2018-03-22   13663927.0
# 2018-03-23   18225390.0
# 2018-03-26   15130542.0
# 2018-03-27   34462113.0

# %%
plt.style.use('fivethirtyeight')
fig,axes = plt.subplots(1,2,figsize=(22,10))

axes[0].plot(intc.index,intc['Adj. Close'],'b')
axes[0].set_title('INTEL Stock')
axes[0].set_ylabel('Price/Share ($)')

axes[1].plot(nvda.index,nvda['Adj. Close'],'r')
axes[1].set_title('NVIDIA Stock')
axes[1].set_ylabel('Price/Share ($)')
# Out:
# Text(0,0.5,'Price/Share ($)')

# %%
intc_shares = {2016:4.88e9, 2017:4.84e9, 2018:4.75e9}
nvda_shares = {2016:.57e9, 2017:.65e9, 2018:.63e9}
intc['Share_num'] = intc.index.year
nvda['Share_num'] = nvda.index.year
intc['Share_num'].replace(to_replace=intc_shares,inplace=True)
nvda['Share_num'].replace(to_replace=nvda_shares,inplace=True)

# %%
intc['Cap'] = intc['Share_num'] * intc['Adj. Close']
nvda['Cap'] = nvda['Share_num'] * nvda['Adj. Close']

# %%
plt.style.use('fivethirtyeight')
fig,axes = plt.subplots(1,1,figsize=(10,6))

axes.plot(intc.index,intc['Cap'],'b',label = 'INTEL')
axes.plot(nvda.index,nvda['Cap'],'r',label = 'NVIDIA')
axes.set_title('INTEL & NVDA Market Cap')
axes.set_ylabel('Market Cap (Hundred Billions $)')
axes.legend()

# %%
import fbprophet as prophet

intc.reset_index(level=0,inplace=True)
nvda.reset_index(level=0,inplace=True)
intc = intc.rename(columns={'Date': 'ds', 'Cap': 'y'})
nvda = nvda.rename(columns={'Date': 'ds', 'Cap': 'y'})

# %%
intc.head()
# Out:
#           ds   Open     High    Low  Close      Volume  Ex-Dividend  \
# 0 2016-01-04  33.88  34.0100  33.46  33.99  27882190.0          0.0
# 1 2016-01-05  33.96  34.0000  33.53  33.83  16709510.0          0.0
# 2 2016-01-06  33.25  33.5200  32.80  33.08  25491255.0          0.0
# 3 2016-01-07  32.28  33.0077  31.84  31.84  37680521.0          0.0
# 4 2016-01-08  32.09  32.2200  31.43  31.51  29953840.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume  \
# 0          1.0  31.707998  31.829664  31.314924   31.810946   27882190.0
# 1          1.0  31.782869  31.820305  31.380436   31.661204   16709510.0
# 2          1.0  31.118387  31.371077  30.697236   30.959285   25491255.0
# 3          1.0  30.210572  30.891620  29.798780   29.798780   37680521.0
# 4          1.0  30.032753  30.154419  29.415064   29.489936   29953840.0
#
#       Share_num             y
# 0  4.880000e+09  1.552374e+11
# 1  4.880000e+09  1.545067e+11
# 2  4.880000e+09  1.510813e+11
# 3  4.880000e+09  1.454180e+11
# 4  4.880000e+09  1.439109e+11

# %%
intc['y'] = intc['y']/1e9
nvda['y'] = nvda['y']/1e9

# %%
intc_prophet = prophet.Prophet(changepoint_prior_scale=.15,daily_seasonality=True)
nvda_prophet = prophet.Prophet(changepoint_prior_scale=.15,daily_seasonality=True)
intc_prophet.fit(intc)
nvda_prophet.fit(nvda)
# Out:
# C:\Users\Justin\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
intc_forecast = intc_prophet.make_future_dataframe(periods=365*2, freq='D')
nvda_forecast = nvda_prophet.make_future_dataframe(periods=365*2, freq='D')

# %%
intc_forecast = intc_prophet.predict(intc_forecast)

# %%
intc_prophet.plot(intc_forecast, xlabel = 'Date', ylabel = 'Market Cap (billions $)');

# %%
nvda_forecast = nvda_prophet.predict(nvda_forecast)

# %%
nvda_prophet.plot(nvda_forecast, xlabel = 'Date', ylabel = 'Market Cap (billions $)');
